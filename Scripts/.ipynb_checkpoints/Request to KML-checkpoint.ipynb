# %% [markdown]
# ## Resultados a KML

# %%
import sys
# !{sys.executable} -m pip install geo2kml
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Requirement already satisfied: geo2kml in /opt/homebrew/lib/python3.9/site-packages (0.0.3)
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#
# [notice] A new release of pip available: 22.2.2 -> 22.3.1
# [notice] To update, run: python3.9 -m pip install --upgrade pip

# %%
from geo2kml import to_kml
from urllib.request import urlopen
import json

# %%
tripId = '10e4fe6b-5164-4f7e-a2be-b6cbc9d7f123'
link = 'http://172.23.215.114:3000/tripStats?tripId=%s'%(tripId)
f = urlopen(link)
myfile = f.read()

# %%
myfile = open('trip12.txt', 'r')
print(myfile)
# Out:
# <_io.TextIOWrapper name='trip12.txt' mode='r' encoding='UTF-8'>

# %%
jsonData = json.loads(myfile)


print(jsonData['realTimeData'][0]['timestamp'])
# Crear un GeoJSON
geoJSON = {
'type': 'Feature',
'properties': {},
'geometry': {},
'type': 'LineString',
'coordinates': [[position['coords']['longitude'], position['coords']['latitude']] for position in jsonData['realTimeData']]
}
kml_str = to_kml(geoJSON)

g = open("tripId-%s.kml"%(tripId), 'w');
g.write(kml_str)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 jsonData = json.loads(myfile)
#       4 print(jsonData['realTimeData'][0]['timestamp'])
#       5 # Crear un GeoJSON
#
# File /opt/homebrew/Cellar/python@3.9/3.9.15/Frameworks/Python.framework/Versions/3.9/lib/python3.9/json/__init__.py:339, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     337 else:
#     338     if not isinstance(s, (bytes, bytearray)):
# --> 339         raise TypeError(f'the JSON object must be str, bytes or bytearray, '
#     340                         f'not {s.__class__.__name__}')
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
#
# TypeError: the JSON object must be str, bytes or bytearray, not TextIOWrapper

# %% [markdown]
# ## Ordenar por Timestamp en vez de orden de escritura

# %%
sortedPings = sorted(jsonData['realTimeData'], key= lambda x: x['timestamp'])
# print(sortedPings)
# Crear un GeoJSON
geoJSON = {
'type': 'Feature',
'properties': {},
'geometry': {},
'type': 'LineString',
'coordinates': [[position['coords']['longitude'], position['coords']['latitude']] for position in sortedPings]
}
kml_str = to_kml(geoJSON)
print(kml_str)
g = open("sortedtripId-%s.kml"%(tripId), 'w');
g.write(kml_str)
# Out:
# <?xml version="1.0" encoding="UTF-8"?><kml><Document><Placemark><LineString><coordinates>-58.4826706,-34.5419966
# -58.4829069,-34.5420977
# -58.4831546,-34.542205
# -58.4834039,-34.5423143
# -58.4836473,-34.5424206
# -58.4838878,-34.5425229
# -58.4841238,-34.5426222
# -58.4843683,-34.5427264
# -58.4846071,-34.5428271
# -58.4848557,-34.5429321
# -58.4851156,-34.5430438
# -58.4853782,-34.5431532
# -58.4856539,-34.5432706
# -58.485928,-34.5433885
# -58.4861797,-34.5434981
# -58.4864255,-34.5436076
# -58.4866939,-34.5437309
# -58.4869702,-34.5438578
# -58.4872539,-34.5439864
# -58.4875237,-34.5441086
# -58.4878034,-34.5442343
# -58.4880826,-34.5443625
# -58.4883675,-34.5444934
